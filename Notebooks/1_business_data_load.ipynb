# %% [markdown]
# <img src = "https://drive.google.com/uc?export=view&id=1qwLiiRwLcW04FUsVd7cC1vZ0MDjG3m2D" alt = "Encabezado MLDS" width = "100%">  </img>

# %% [markdown]
# # **Proyecto (Fase 1):** Reconocimiento vocal de ceatáceos
# ## **Giovanny Alejandro Cuervo Londoño**

# %% [markdown]
# # **Entendimiento del Negocio y Carga de Datos**
# ---
#
# Este notebook es una plantilla que le puede servir como guía para el primer entregable del proyecto aplicado.

# %% [markdown]
# ## **1. Marco de Proyecto**
# ---
#
# Normalmente, se suele construir un marco de proyecto para mostrar los resultados del entendimiento del negocio, es decir, debemos dar respuesta a los siguientes elementos:

# %% [markdown]
# ### **1.1. Trasfondo del Negocio**
# ---
#
# - ¿Quién es el cliente o los beneficiarios del proyecto? ¿En qué dominio se encuentran (marketing, medicina, entre otros)?
# - ¿Qué problemas del negocio o del dominio estamos tratando de solucionar?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
# > Este proyecto de conservación marina tendría múltiples beneficios para diferentes sectores de la sociedad. Organizaciones de conservación y medio ambiente junto con la comunidad científica y académica tienen como objetivo la protección e investigación de los ecosistemas marinos por medio del estudio e identificación de los factores que los afectan. Ademas, la conservación de estas comunidades de mamíferos puede beneficiar a las poblaciones costeras y empresas pesqueras que dependen de la disponibilidad de múltiples recursos marinos para su sustento. Esto también puede mejorar la economía de la región, dado que el desarrollo de industrias sostenibles como el ecoturismo de avistamiento y observación de mamíferos marinos puede traer nuevas oportunidades para la economía de la población local.
#
# > En los últimos años se ha reportado una reducción en la abundancia y un cambio en la distribución de las comunidades de mamíferos marinos debido a la alteración de sus hábitats por factores como: cambio climático, sobreexplotación pesquera y contaminación química y sonora; dichos factores están provocando la pérdida de múltiples ecosistemas, alterando así la disponibilidad de recursos para el sustento de esta comunidad. Aunque estos factores pueden afectar en diferentes niveles a cada especie de dicha comunidad, resulta importante desarrollar proyectos para su conservación en función mantener la biodiversidad y el equilibrio ecológico de los océanos.

# %% [markdown]
# ### **1.2. Alcance**
# ---
#
# - ¿Qué  solución basada en _Deep Learning_ queremos implementar?
# - ¿Qué  se hará?
# - ¿De qué forma el cliente o beneficiario utilizará el producto del proyecto?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
# > Este proyecto pretende implementar un modelo óptimo de *deep learning* (según el principio de parsimonia) para identificar diferentes especies de mamíferos marinos utilizando sus vocalizaciones características, utilizando distintos algunos tipos de arquitecturas basadas en `tensorflow`. Se pretende que dicho modelo promueva el desarrollo económico y científico de las zonas costeras de Colombia beneficiando ha múltiples sectores de la sociedad.
#
# > Se utilizará la base de datos [Watkins Marine Mammal Sound Database](https://cis.whoi.edu/science/B/whalesounds/index.cfm) compuesta de aproximadamente 2000 registros sonoros de más de 60 especies de mamíferos marinos. Dentro de este basto conjunto de datos se tomarán los "mejores audios" que comprenden un subconjunto de la base de datos de 1697 audios con 32 clases o especies.
# Dicho conjunto de datos deberá ser explorado a través de un Análisis Exploratorio de Datos (EDA) para identificar desbalance entre las categorías y formular estrategias de preprocesamiento. Finalmente, se pretende utilizar diferentes métricas para evaluar algunas arquitecturas y combinaciones hiperparámetros para encontrar el modelo más eficiente que permita identificar mamíferos marinos utilizando sus sonidos.
#
# > Este producto permite monitorear la abundancia y distribución de las comunidades de mamíferos marinos para su conservación e investigación. Adicionalmente, permite que otros sectores como el de turismo ecológico pueda identificar nuevas áreas de avistamiento de mamíferos que le permitan formular nuevos planes destinos para turismo responsable.

# %% [markdown]
# ### **1.3. Plan**
# ---
#
# Puede agregar una lista de actividades con tiempos estimados, un diagrama de Gantt o integrar alguna herramienta de gestión de proyectos para mostrar la planeación del proyecto.

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
# > ![image.png](data:image/png;base64,...)

# %% [markdown]
# > El diagrama de Gantt expuesto muestra el plan de trabajo detallado junto con la tareas necesarias para llevar acabo el proyecto. Este proyecto tendrá una duración de 36 días, iniciando 14 de abril y finalizando el 19 de mayo, dicho periodo de tiempo estará distribuido en 5 fases:
# * **Fase 1** 🟡:  En esta fase se planeta el entendimiento del negocio y la carga de datos, iniciando el 14 de abril y finalizando 25 de abril.
# * **Fase 2** 🟢: En esta se plantea realizar un análisis exploratorio de datos (EDA) con el objetivo de entender y prepara los datos, esto se realizará entre el 26 de abril y el 2 de mayo.
# * **Fase 3** 🔵: Aquí se plantearán múltiples diseños e implementaciones de los modelos de *Deep learning* para el procesamiento de audios (recurrentes, convolucionales, entre otros), esto se hará entre el 3 y 9 de mayo.
# * **Fase 4** 🟠: Posteriormente, se realizará el entrenamiento y validación de dichos modelos con el conjunto de entrenamiento utilizando las métricas, funciones de perdida y de activación apropiadas, esto irá  del 10 y 16 de mayo.
# * **Fase 5** 🔴: Finalmente, en esta fase se realizará la evaluación de los modelos planteados seleccionando así el más óptimo según su precisión y cantidad de parámetros. Cada una de las fases planteadas se expondrán de forma breve con un vídeo y un notebook de jupyter donde se explicará el proyecto, esta fase se llevará acabo entre el 17 y 19 de mayo.

# %% [markdown]
# ## **2. Datos**
# ---
#
# En esta sección debe adjuntar una descripción de los datos y agregar el código que permite su tratamiento.

# %% [markdown]
# ### **2.1. Origen**
# ---
#
# - ¿De dónde vienen los datos?
# - ¿Se usa alguna herramienta o proceso para la descarga de la información?
# - ¿Qué tipo de datos estamos manejando?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
#
# > El conjunto fue extraído de la base de datos de datos [Watkins Marine Mammal Sound Database](https://cis.whoi.edu/science/B/whalesounds/index.cfm) la cual almacena 2000 vocalizaciones de mamíferos marinos de 60 especies diferentes. Para este proyecto se utilizará el subconjunto de "mejores audios" constituido por 1697 audios de 32 clases o especies.
#
# > Para la descarga de dichos datos se utilizarán técnicas de web scraping por medio de herramientas como: `Selenium`, `bs4`, `requests` y `fake_useragent`.
#
# > Los datos se componen de 1697 audios en formato mp4 con un duración promedio de 10 segundos, un bitrate promedio de de 920 kbps y de un canal (mono).
#
# |N| Formato| Duración $\bar{x}$|Bitrate $\bar{x}$|Sample rate $\bar{x}$| Canal |
# |-----|-----|------|----------|---------|------|
# | 1697 | wav | 10 s | 920 kbps | 57788 Hz | mono |

# %% [markdown]
# |N| Categorías | Formato| Duración $\bar{x}$|Bitrate $\bar{x}$|Sample rate $\bar{x}$| Canal |
# |-----|-----|------|----------|---------|------|------|
# | 15567 | 55 | wav | 10 s | 920 kbps | 57788 Hz | mono |

# %% [markdown]
# ### **2.2. Carga o Adquisición de Datos**
# ---
#
# Agregue el código necesario en _Python_ para obtener o cargar los datos.

# %%
# %%shell
# # Ubuntu ya no distribuye chromium-browser fuera de snap
# # Solución propuesta en:  https://askubuntu.com/questions/1204571/how-to-install-chromium-without-snap
# # Agregar debian buster
# cat > /etc/apt/sources.list.d/debian.list <<'EOF'
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster.gpg] http://deb.debian.org/debian buster main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster-updates.gpg] http://deb.debian.org/debian buster-updates main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-security-buster.gpg] http://deb.debian.org/debian-security buster/updates main
# EOF
#
# # Agregar keys
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
#
# apt-key export 77E11517 | gpg --dearmour -o /usr/share/keyrings/debian-buster.gpg
# apt-key export 22F3D138 | gpg --dearmour -o /usr/share/keyrings/debian-buster-updates.gpg
# apt-key export E562B32A | gpg --dearmour -o /usr/share/keyrings/debian-security-buster.gpg
#
# # Preferir repositorio de debian solo para paquetes de chromium*
# # Nota las líneas en blanco dobles entre las entradas
# cat > /etc/apt/preferences.d/chromium.pref << 'EOF'
# Package: *
# Pin: release a=eoan
# Pin-Priority: 500
#
#
# Package: *
# Pin: origin "deb.debian.org"
# Pin-Priority: 300
#
#
# Package: chromium*
# Pin: origin "deb.debian.org"
# Pin-Priority: 700
# EOF
#
# # Instalar chromium y chromium-driver
# apt-get update
# apt-get install chromium chromium-driver
# Out:
# Executing: /tmp/apt-key-gpghome.lthOmFVfbg/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# gpg: key DCC9EFBF77E11517: public key "Debian Stable Release Key (10/buster) <debian-release@lists.debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.M1mXHKZDDB/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# gpg: key DC30D7C23CBBABEE: public key "Debian Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.mZ89wy9KXE/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
# gpg: key 4DFAB270CAA96DFA: public key "Debian Security Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# ...

# %%
# Modulos instalados
# !pip install fake_useragent
# !pip install selenium

# Modulos importados
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from fake_useragent import UserAgent
import numpy as np
import time, re, os, requests
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-blink-features=AutomationControlled')
options.add_experimental_option('useAutomationExtension', False)
options.add_experimental_option("excludeSwitches", ["enable-automation"])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 2.7 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# ...

# %%
ua = UserAgent()
user_agent = ua.random
options.add_argument(f'user-agent={user_agent}')
print(user_agent)
# Out:
# Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.66 Safari/535.11

# %%
#Timepo de espera con una Distribución de probabilidad lognormal
def distriProb_lognorm():
  pdf = np.random.lognormal(mean=2.0, sigma=0.5, size=(1))
  if pdf<3  or pdf>7:
    pdf=np.random.randint(3,6)
  return float(pdf)

# %%
# Recopila los links de cada una de las 32 especies de mamaiferos marinos y retorna un dicionario {especie : link}:
directorio= os.getcwd()
print(f'Directorio actual es: {directorio}')

#cambiamos el directorio por el de la carpeta que trabajaremos
print('#######PASO 1######')
#en mi caso es: /content/ Notebooks/IA y AP/Proyecto/Audios
os.chdir('/content/')
directorio= os.getcwd()

#########PASO 1#############
#colocamos la ruta del buscador que vayamos a usar en este caso Chrome
driver =  webdriver.Chrome('chromedriver',options=options)

#colocamos el link de la pagina donde queremos hacer la busqueda
try:
    driver.get('https://cis.whoi.edu/science/B/whalesounds/index.cfm')
except:
    print('Hubo un error de conexion intentando de nuevo...')
    time.sleep(distriProb_lognorm())   
    driver.refresh()
    driver.get('https://cis.whoi.edu/science/B/whalesounds/index.cfm')
    
time.sleep(distriProb_lognorm())
#filtramos las etiquetas de html con la caracteristica que buscamos
soup = BeautifulSoup(driver.page_source, 'html.parser')
html_links = soup.find_all('option', {'value' : True})

whale= {}

for link, idx in zip(html_links, range(len(html_links))):
    name = html_links[idx].text
    m = re.search(' \n\t\t', name)
    if m == None:
        continue
    key = name[:m.start()] + name[m.end():]
    whale[key]= link.get('value')
    
print('\nDiccionario {Especie: link}:', whale)
# Out:
# Directorio actual es: /content
# #######PASO 1######
#
# ...

# %%
# Itera en el diccionario para ir a cada especie y descargar el audio
for link, name, num in zip(whale.values(), whale.keys(), range(len(whale.values()))):  
    driver.get(link)
    time.sleep(distriProb_lognorm())
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    video_links = soup.table.find_all('source', {'src' : True}, src = True)
    print(f'\nBuscando: {name} '+ str(num+1)+'/'+str(len(whale.values())))
    for link, i in zip(video_links, range(len(video_links))):
        ua = UserAgent()
        headers = {'User-Agent': ua.random}

        #solicitamos el codigo html de la pagina
        ruta = 'https://whoicf2.whoi.edu' + link.get('src')
        time.sleep(distriProb_lognorm())
        result = requests.get(ruta, allow_redirects=True, headers=headers)
        print(f'\nDescargando: {ruta[-12:]} como {name+str(i+1)}.mp4')
        open(name+str(i+1)+'.mp4', 'wb').write(result.content)
        print(f'Archivo {name+str(i+1)}.mp4 descargado!')

print('\n¡Listo!--> Base de datos descargada')
# Out:
# Buscando: Atlantic Spotted Dolphin 1/32
#
# Descargando: 61025001.wav como Atlantic Spotted Dolphin1.mp4
# Archivo Atlantic Spotted Dolphin1.mp4 descargado!
#
# Descargando: 61025002.wav como Atlantic Spotted Dolphin2.mp4
# Archivo Atlantic Spotted Dolphin2.mp4 descargado!
#
# Descargando: 61025003.wav como Atlantic Spotted Dolphin3.mp4
# Archivo Atlantic Spotted Dolphin3.mp4 descargado!
#
# Descargando: 61025004.wav como Atlantic Spotted Dolphin4.mp4
# Archivo Atlantic Spotted Dolphin4.mp4 descargado!
#
# Descargando: 61025006.wav como Atlantic Spotted Dolphin5.mp4
# Archivo Atlantic Spotted Dolphin5.mp4 descargado!
#
# Descargando: 61025007.wav como Atlantic Spotted Dolphin6.mp4
# Archivo Atlantic Spotted Dolphin6.mp4 descargado!
#
# Descargando: 61025008.wav como Atlantic Spotted Dolphin7.mp4
# Archivo Atlantic Spotted Dolphin7.mp4 descargado!
#
# Descargando: 61025009.wav como Atlantic Spotted Dolphin8.mp4
# Archivo Atlantic Spotted Dolphin8.mp4 descargado!
#
# ...

# %% [markdown]
# > 💬 La **última celda se detuvo a propósito** dado que el proceso de descarga puede durar horas y la base de datos ya había sido  descargada previamente. Pero el *ouput* de la celda evidencia que el código implementado funciona para la obtención de los audios.

# %% [markdown]
# ## **Créditos**
#
# * **Profesor:** [Fabio Augusto Gonzalez](https://dis.unal.edu.co/~fgonza/)
# * **Asistentes docentes :**
#   * [Santiago Toledo Cortés](https://sites.google.com/unal.edu.co/santiagotoledo-cortes/)
# * **Diseño de imágenes:**
#     - [Mario Andres Rodriguez Triana](https://www.linkedin.com/in/mario-andres-rodriguez-triana-394806145/).
# * **Coordinador de virtualización:**
#     - [Edder Hernández Forero](https://www.linkedin.com/in/edder-hernandez-forero-28aa8b207/).
#
# **Universidad Nacional de Colombia** - *Facultad de Ingeniería*
